# %% [markdown]
# <a href="https://colab.research.google.com/github/kilos11/Data_Science/blob/main/Classifying_Digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Random Forest for Classifying Digits

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
digits = load_digits()
digits.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
import matplotlib.pyplot as plt

# Create a new figure with a size of 6x6 inches
fig = plt.figure(figsize=(6, 6))

# Adjust the spacing of the subplots within the figure
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# Iterate over a range of 64 (assuming 'digits' is a dataset containing images)
for i in range(64):
    # Add a subplot to the figure with a 8x8 grid and incrementing the subplot position
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])

    # Display the image at index 'i' from the 'digits' dataset using a binary colormap
    ax.imshow(digits.images[i], cmap=plt.cm.binary, interpolation='nearest')

    # Add a text annotation at the bottom left corner of the subplot, showing the target value
    ax.text(0, 7, str(digits.target[i]))

'''In this code:

- The code imports the necessary module `matplotlib.pyplot` as `plt`.
- A new figure object (`fig`) is created with a size of 6x6 inches using `plt.figure(figsize=(6, 6))`.
- The spacing between subplots is adjusted using `fig.subplots_adjust()` to set the margins and the spacing between subplots.
- A loop is used to iterate over a range of 64, assuming that the variable `digits` is a dataset containing images.
- For each iteration, a subplot is added to the figure using `fig.add_subplot()` with a 8x8 grid and an incrementing subplot position.
- The image at index `i` from the `digits` dataset is displayed within the subplot using `ax.imshow()`. The colormap is set to binary for displaying grayscale images.
- A text annotation is added at the bottom left corner of the subplot using `ax.text()`, displaying the target value associated with the image.'''
# Out:
# 'In this code:\n\n- The code imports the necessary module `matplotlib.pyplot` as `plt`.\n- A new figure object (`fig`) is created with a size of 6x6 inches using `plt.figure(figsize=(6, 6))`.\n- The spacing between subplots is adjusted using `fig.subplots_adjust()` to set the margins and the spacing between subplots.\n- A loop is used to iterate over a range of 64, assuming that the variable `digits` is a dataset containing images.\n- For each iteration, a subplot is added to the figure using `fig.add_subplot()` with a 8x8 grid and an incrementing subplot position.\n- The image at index `i` from the `digits` dataset is displayed within the subplot using `ax.imshow()`. The colormap is set to binary for displaying grayscale images.\n- A text annotation is added at the bottom left corner of the subplot using `ax.text()`, displaying the target value associated with the image.'

# %%
# Split the data into training and testing sets
Xtrain, Xtest, ytrain, ytest = train_test_split(digits.data, digits.target, random_state=0)

# Create a KNeighborsClassifier with 1000 estimators
knn = KNeighborsClassifier(n_estimators=1000)
# Train the model using the training data
model.fit(Xtrain, ytrain)

# Make predictions on the test data
ypred = model.predict(Xtest)
# Compute the confusion matrix using the true labels (ytest) and predicted labels (ypred)
mat = confusion_matrix(ytest, ypred)

# Create a heatmap of the transposed confusion matrix
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)

# Set the x-axis label
plt.xlabel('true label')

# Set the y-axis label
plt.ylabel('predicted label')
ypred = model.predict(Xtest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b3a4ca6bc56c> in <cell line: 5>()
#       3
#       4 # Create a KNeighborsClassifier with 1000 estimators
# ----> 5 knn = KNeighborsClassifier(n_estimators=1000)
#       6 # Train the model using the training data
#       7 model.fit(Xtrain, ytrain)
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
print(ypred)
# Out:
# [2 8 2 6 6 7 1 9 8 5 2 8 6 6 6 6 1 0 5 8 8 7 8 4 7 5 4 9 2 9 4 7 6 8 9 4 3
#  1 0 1 8 6 7 7 1 0 7 6 2 1 9 6 7 9 0 0 5 1 6 3 0 2 3 4 1 9 2 6 9 1 8 3 5 1
#  2 8 2 2 9 7 2 3 6 0 5 3 7 5 1 2 9 9 3 1 7 7 4 8 5 8 5 5 2 5 9 0 7 1 4 7 3
#  4 8 9 7 9 8 0 6 5 2 5 3 4 1 7 0 6 1 5 5 9 9 5 9 9 5 7 5 6 2 8 6 9 6 1 5 1
#  5 9 9 1 5 3 6 1 8 9 7 7 6 7 6 5 6 0 8 8 9 8 6 1 0 4 1 6 3 8 6 7 4 9 6 3 0
#  3 3 3 0 7 7 5 7 8 0 7 8 9 6 4 5 0 1 4 6 4 3 3 0 9 5 9 2 1 4 2 1 6 8 9 2 4
#  9 3 7 6 2 3 3 1 6 9 3 6 3 2 2 0 7 6 1 1 9 7 2 7 8 5 5 7 5 2 3 7 2 7 5 5 7
#  0 9 1 6 5 9 7 4 3 8 0 3 6 4 6 3 2 6 8 8 8 4 6 7 5 2 4 5 3 2 4 6 9 4 5 4 3
#  4 6 2 9 0 1 7 2 0 9 6 0 4 2 0 7 9 8 5 7 8 2 8 4 3 7 2 6 9 1 5 1 0 8 2 5 9
#  5 6 8 2 7 2 1 5 1 6 4 5 0 9 4 1 1 7 0 8 9 0 5 4 3 8 8 6 5 3 4 4 4 8 8 7 0
#  9 6 3 5 2 3 0 8 8 3 1 3 3 0 0 4 6 0 7 7 6 2 0 4 4 2 3 7 8 9 8 6 8 5 6 2 2
#  3 1 7 7 8 0 3 3 2 1 5 5 9 1 3 7 0 0 7 0 4 5 9 3 3 4 3 1 8 9 8 3 6 2 1 6 2
#  1 7 5 5 1 9]

# %%
print(metrics.classification_report(ypred, ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        38
#            1       0.98      0.98      0.98        43
#            2       0.98      1.00      0.99        43
#            3       0.98      0.98      0.98        45
#            4       0.97      1.00      0.99        37
#            5       0.98      0.96      0.97        49
#            6       1.00      1.00      1.00        52
#            7       1.00      0.96      0.98        50
#            8       0.94      0.98      0.96        46
#            9       0.98      0.98      0.98        47
#
#     accuracy                           0.98       450
#    macro avg       0.98      0.98      0.98       450
# weighted avg       0.98      0.98      0.98       450

# %%
# Compute the confusion matrix using the true labels (ytest) and predicted labels (ypred)
mat = confusion_matrix(ytest, ypred)

# Create a heatmap of the transposed confusion matrix
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)

# Set the x-axis label
plt.xlabel('true label')

# Set the y-axis label
plt.ylabel('predicted label')
# Out:
# Text(113.9222222222222, 0.5, 'predicted label')
